# %%
#importamos librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ***Excel Datos de Facturación***

# %%
datadf=pd.read_excel("Gastos y costos 20-23.xlsx",skiprows=5,sheet_name='2020')
datadf.head(3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 datadf=pd.read_excel("Gastos y costos 20-23.xlsx",skiprows=5,sheet_name='2020')
#       2 datadf.head(3)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
# ...

# %%
datadf1=pd.read_excel("Gastos y costos 20-23.xlsx",skiprows=5,sheet_name='2021')
datadf1.head(3)
# Out:
#   2021-01-01 00:00:00 0001010100752163714102  \
# 0          2021-01-01                  19788
# 1          2021-01-01                 211781
# 2          2021-01-01                 211782
#
#    B8AEDE83-CC76-404C-A611-6B5A87BA561F  BNM840515VB1  \
# 0  19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7  ESI9612311E7
# 1  EAB26414-DD9A-4E8F-9F5C-05FE24D98E48  BLE1512082R9
# 2  C16F79B5-FB35-4BFC-AF84-708B24F500BB  BLE1512082R9
#
#            BANCO NACIONAL DE MEXICO, S.A.         COMISION BANCARIA  \
# 0  ELECTRONICOS Y SIMILARES, S.A. DE C.V.                   COMPRAS
# 1            BEPENSA LEASING S.A. DE C.V.  ARRENDAMIENTO FINANCIERO
# 2            BEPENSA LEASING S.A. DE C.V.  ARRENDAMIENTO FINANCIERO
#
#                                     COMISION COBRADA  PUE    1      345  \
# 0                        MOTO E7 PLUS AZUL 64GB 4RAM  PUE  1.0  3447.41
# 1  AA RENTA EXIGIBLE CL0000006876 6/36 de 03/12/2...  PPD  1.0  5551.38
# ...

# %%
datadf2=pd.read_excel("Gastos y costos 20-23.xlsx",skiprows=5,sheet_name='2022')
datadf2.head(3)
# Out:
#   2022-01-01 00:00:00        280109  7E00E776-A839-4D57-B291-411109164B2F  \
# 0          2022-01-01  007817297284  BB6585C1-3B54-4130-AFD0-1867C3764821
# 1          2022-01-01          5595  B5E4B4EB-6C2F-11EC-BB9D-00155D014009
# 2          2022-01-01          5614  BB6756D1-6CCD-11EC-947D-00155D014407
#
#     BLE1512082R9      BEPENSA LEASING S.A. DE C.V. ARRENDAMIENTO FINANCIERO  \
# 0   BNM840515VB1    BANCO NACIONAL DE MEXICO, S.A.        COMISION BANCARIA
# 1  ZEGC530520V4A  CARLOS ENRIQUE ZERMEÑO GUTIERREZ                  COMPRAS
# 2  ZEGC530520V4A  CARLOS ENRIQUE ZERMEÑO GUTIERREZ                  COMPRAS
#
#   AA RENTA EXIGIBLE CL0000006877 18/36 de 03/12/2021 a 02/01/2022  PPD    1  \
# 0                           Servicios de Facturación               PUE  1.0
# 1                                               Pago               NaN  1.0
# 2                                               Pago               NaN  1.0
#
# ...

# %%
datadf3=pd.read_excel("Gastos y costos 20-23.xlsx",skiprows=5,sheet_name='2023')
datadf3.head(3)
# Out:
#   2023-01-01 00:00:00      38  20FBB63B-D550-512F-9668-EEC6F983CEB7  \
# 0          2023-01-01  341932  DB8C4388-D4E0-4F0C-A09C-77C773257F44
# 1          2023-01-01  341933  A81A63F5-D5EC-4601-803E-375AF9CC5021
# 2          2023-01-01  342205  DCC10492-DE51-4C87-8430-5676FBF81931
#
#    AAE6411055P8     AESA ARTICULOS ELECTRICOS                   COMPRAS  \
# 0  BLE1512082R9  BEPENSA LEASING S.A. DE C.V.  ARRENDAMIENTO FINANCIERO
# 1  BLE1512082R9  BEPENSA LEASING S.A. DE C.V.  ARRENDAMIENTO FINANCIERO
# 2  BLE1512082R9  BEPENSA LEASING S.A. DE C.V.  ARRENDAMIENTO FINANCIERO
#
#                                                 Pago Unnamed: 7  Unnamed: 8  \
# 0  AA RENTA EXIGIBLE CL0000006876 30/36 de 03/12/...        PPD        99.0
# 1  AA RENTA EXIGIBLE CL0000006877 30/36 de 03/12/...        PPD        99.0
# 2  AA RENTA EXIGIBLE CL0000009486 5/48 de 03/12/2...        PPD        99.0
#
#      1        0      0.1  0.2  0.3  Unnamed: 14      0.4      0.5  P  Vigente  \
# ...

# %%
# Out:
# FECHA             0
# FOLIO           189
# UUID              0
# RFC               0
# PROVEEDOR         0
# TIPO GASTO        0
# GASTO          2502
# DESCRIPCION       0
# TC              391
# IMPORTE          34
# IVA             268
# RET ISR           0
# RET IVA           0
# TOTAL MX          0
# TOTAL SAT         0
# TIPO              1
# STATUS            0
# POLIZA         3321
# Columna1          0
# dtype: int64

# %%
# Out:
# FECHA             0
# FOLIO             0
# UUID              0
# RFC               0
# PROVEEDOR         0
# TIPO GASTO        0
# GASTO          2502
# DESCRIPCION       0
# TC              391
# IMPORTE          34
# IVA             268
# RET ISR           0
# RET IVA           0
# TOTAL MX          0
# TOTAL SAT         0
# TIPO              1
# STATUS            0
# POLIZA         3321
# Columna1          0
# dtype: int64
